# %%
from threaded_sweep import Sweep1D, Sweep0D, Sweep2D
from daq_driver import Daq, DaqAOChannel, DaqAIChannel
import nidaqmx
import time
import numpy as np
import qcodes as qc
from util import init_database
from tracking import *
from qcodes.dataset.measurements import Measurement
from qcodes.dataset.database import initialise_or_create_database_at
from qcodes.dataset.data_export import get_data_by_id
from qcodes.instrument_drivers.oxford.IPS120 import OxfordInstruments_IPS120

# %%
magnet = OxfordInstruments_IPS120("magnet", "GPIB0::25::INSTR", use_gpib=True)

# %% [markdown]
# ## Initialize the magnet settings here

# %%
magnet.remote_status(3)
magnet.sweeprate_field(0.2)
# Out:
# 'Tesla, Magnet sweep: fast'

# %%
target_field = 0
# Out:
# 0.0

# %%
magnet.switch_heater(1)
magnet.field_setpoint(target_field)

# %%
str(magnet.field)
# Out:
# 'magnet1_field'

# %%
magnet.remote_status()
# Out:
# 'Local and locked'

# %%
magnet.field()
# Out:
# 0.0

# %%
magnet.mode2()
# Out:
# 'At rest'

# %%
magnet.activity()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-8069dc668f4b> in <module>
# ----> 1 magnet.activity()
#
# c:\users\nanouser\documents\qcodes\qcodes\instrument\parameter.py in __call__(self, *args, **kwargs)
#     341         if len(args) == 0:
#     342             if hasattr(self, 'get'):
# --> 343                 return self.get()
#     344             else:
#     345                 raise NotImplementedError('no get cmd found in' +
#
# c:\users\nanouser\documents\qcodes\qcodes\instrument\parameter.py in get_wrapper(*args, **kwargs)
#     466             except Exception as e:
#     467                 e.args = e.args + ('getting {}'.format(self),)
# --> 468                 raise e
#     469
#     470         return get_wrapper
#
# c:\users\nanouser\documents\qcodes\qcodes\instrument\parameter.py in get_wrapper(*args, **kwargs)
#     422             try:
#     423                 # There might be cases where a .get also has args/kwargs
# --> 424                 value = get_function(*args, **kwargs)
#     425                 self.raw_value = value
#     426
#
# c:\users\nanouser\documents\qcodes\qcodes\utils\command.py in __call__(self, *args)
#     175             raise TypeError(
#     176                 'command takes exactly {} args'.format(self.arg_count))
# --> 177         return self.exec_function(*args)
#
# c:\users\nanouser\documents\qcodes\qcodes\instrument_drivers\oxford\IPS120.py in _get_activity(self)
#     651         self.log.info('Get activity of the magnet.')
#     652         result = self._execute('X')
# --> 653         return status[int(result[4])]
#     654
#     655     def _set_activity(self, mode):
#
# NameError: ("name 'status' is not defined", 'getting magnet1_activity')

# %%
int(magnet._execute('X')[4])
# Out:
# 4

# %%
import os
os.environ['MeasureItHome']
# Out:
# 'C:\\Users\\nanouser\\Documents\\MeasureIt'
